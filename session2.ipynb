# %% [markdown]
# #**UNDERSTANDING VARIOUS OPERATIONS ON DATAFRAMES WITH PANDAS**

# %% [markdown]
# Importing numpy and pandas library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the dataframe from an external .csv file

# %%
dataset=pd.read_csv('/content/melbourne_ta_reviews.csv')

# %% [markdown]
# #**.head()**
# Prints the first 5 columns of the dataframe

# %%
dataset.head()
# Out:
#                            name  rankingPosition priceLevel    category  \
# 0  Hopetoun Tea Rooms est. 1892               26   $$ - $$$  restaurant
# 1             Da Guido La Pasta                2   $$ - $$$  restaurant
# 2                Foglia di Fico                3   $$ - $$$  restaurant
# 3            Pidapipo Gelateria               11          $  restaurant
# 4                      Kazuki's                9       $$$$  restaurant
#
#    rating                                            address  numberOfReviews
# 0     4.5  421 Bourke St Hopetoun Tea Rooms, Melbourne, V...             2311
# 1     4.5  130 Lygon St Carlton, Melbourne, Victoria 3053...             1095
# 2     5.0  585 La Trobe St (Spencer St entrance), Melbour...              202
# 3     4.5  299 Lygon St, Carlton, Melbourne, Victoria 305...              433
# 4     4.5  121 Lygon St Carlton, Melbourne, Victoria 3053...              500

# %% [markdown]
# accessing columns from the beginning to a particular index

# %%
dataset.head(20)
# Out:
#                                        name  rankingPosition priceLevel  \
# 0              Hopetoun Tea Rooms est. 1892               26   $$ - $$$
# 1                         Da Guido La Pasta                2   $$ - $$$
# 2                            Foglia di Fico                3   $$ - $$$
# 3                        Pidapipo Gelateria               11          $
# 4                                  Kazuki's                9       $$$$
# 5                                Hochi Mama               17   $$ - $$$
# 6                                     Sezar               18   $$ - $$$
# 7                      The French Brasserie               19       $$$$
# 8         The Railway Club Hotel Steakhouse               24   $$ - $$$
# 9                           Bistrot d'Orsay               29   $$ - $$$
# 10                             Da Guido 365                7   $$ - $$$
# 11                  Roule Galette Melbourne                8          $
# ...

# %% [markdown]
# #**.tail()**
# Prints the last 5 rows of the dataframe

# %%
dataset.tail()
# Out:
#                     name  rankingPosition priceLevel    category  rating  \
# 495           Bella Cosi              446   $$ - $$$  restaurant     4.5
# 496  At Ease - Easy Thai              437          $  restaurant     4.5
# 497        Lolo and Wren              436   $$ - $$$  restaurant     4.5
# 498            Thai city              438   $$ - $$$  restaurant     4.5
# 499          Tokui Sushi              429          $  restaurant     5.0
#
#                                                address  numberOfReviews
# 495    71 Beach St, Melbourne, Victoria 3207 Australia               71
# 496  195 Lonsdale St, Melbourne, Victoria 3000 Aust...               75
# 497  484 Albion St West Brunswick, Melbourne, Victo...               84
# 498  124 Lygon Street Carlton, Melbourne, Victoria ...               72
# 499  260 Lonsdale St, Melbourne, Victoria 3000 Aust...               50

# %% [markdown]
# accessing rows from the *end* to a particular index

# %%
dataset.tail(15)
# Out:
#                          name  rankingPosition priceLevel    category  rating  \
# 485         The Hardware Club              218   $$ - $$$  restaurant     5.0
# 486        Cornish Arms Hotel                4   $$ - $$$  restaurant     4.0
# 487                     D.O.C              356   $$ - $$$  restaurant     4.0
# 488            Cafe Cavallino              410   $$ - $$$  restaurant     4.0
# 489          Jungle Juice Bar              393          $  restaurant     4.5
# 490      Three Bags Full Cafe                2   $$ - $$$  restaurant     4.5
# 491           Chinta Ria Soul               18   $$ - $$$  restaurant     4.0
# 492           Atta Restaurant                2   $$ - $$$  restaurant     4.5
# 493  Park Street Pasta & Wine              443   $$ - $$$  restaurant     4.5
# 494       The Pancake Parlour              411   $$ - $$$  restaurant     4.0
# 495                Bella Cosi              446   $$ - $$$  restaurant     4.5
# ...

# %% [markdown]
# #**.shape**
# Returns the number of rows and columns of a dataframe

# %%
dataset.shape
# Out:
# (500, 7)

# %% [markdown]
# #**.size**
# Returns the total number of cells of a dataframe

# %%
dataset.size
# Out:
# 3500

# %% [markdown]
# #**.columns**
# returns the name of the columns and the data type of column name

# %%
dataset.columns
# Out:
# Index(['name', 'rankingPosition', 'priceLevel', 'category', 'rating',
#        'address', 'numberOfReviews'],
#       dtype='object')

# %% [markdown]
# #**.dtypes**
# returns the datatype of each column

# %%
dataset.dtypes
# Out:
# name                object
# rankingPosition      int64
# priceLevel          object
# category            object
# rating             float64
# address             object
# numberOfReviews      int64
# dtype: object

# %% [markdown]
# #**.info()**
# provides generic information of the dataframe

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             500 non-null    object
#  1   rankingPosition  500 non-null    int64
#  2   priceLevel       500 non-null    object
#  3   category         500 non-null    object
#  4   rating           500 non-null    float64
#  5   address          500 non-null    object
#  6   numberOfReviews  500 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 27.5+ KB

# %% [markdown]
# #**.describe()**
# returns Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.

# %%
dataset.describe()
# Out:
#        rankingPosition     rating  numberOfReviews
# count       500.000000  500.00000       500.000000
# mean        159.512000    4.32200       411.656000
# std         131.672401    0.28013       487.543585
# min           1.000000    3.50000        41.000000
# 25%          21.750000    4.00000       150.750000
# 50%         145.500000    4.50000       260.000000
# 75%         271.250000    4.50000       472.000000
# max         446.000000    5.00000      6029.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['rankingPosition'].plot(kind='hist', bins=20, title='rankingPosition')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# #**Slicing of dataframe**

# %%
print(dataset[0:5]['rating'])
# Out:
# 0    4.5
# 1    4.5
# 2    5.0
# 3    4.5
# 4    4.5
# Name: rating, dtype: float64

# %% [markdown]
# #**.loc**
# Access a group of rows and columns by label(s) or a boolean array.
#
# .loc[] is primarily label based, but may also be used with a boolean array.

# %%
print(dataset.loc[10:300,['rating','name']])
# Out:
#      rating                             name
# 10      4.5                     Da Guido 365
# 11      4.5          Roule Galette Melbourne
# 12      4.5                       Eau De Vie
# 13      4.5                          Tipo 00
# 14      4.5              Ruyi Modern Chinese
# ..      ...                              ...
# 296     4.0  Melbourne Hwaro Korean Barbecue
# 297     4.5                       Journeyman
# 298     4.5                 Square & Compass
# 299     4.5       Amaru Melbourne Restaurant
# 300     4.0                 Don Don Japanese
#
# [291 rows x 2 columns]

# %%
print(dataset.loc[10:300:2,['rating','name']])
# Out:
#      rating                             name
# 10      4.5                     Da Guido 365
# 12      4.5                       Eau De Vie
# 14      4.5              Ruyi Modern Chinese
# 16      4.5                         Longrain
# 18      4.5          Patricia Coffee Brewers
# ..      ...                              ...
# 292     4.5                        Peko Peko
# 294     4.0    Tsindos-The Greeks Restaurant
# 296     4.0  Melbourne Hwaro Korean Barbecue
# 298     4.5                 Square & Compass
# 300     4.0                 Don Don Japanese
#
# [146 rows x 2 columns]

# %% [markdown]
# #**.iloc**
# Purely integer-location based indexing for selection by position.
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.

# %%
print(dataset.iloc[10:300,[2,3]])
# Out:
#     priceLevel    category
# 10    $$ - $$$  restaurant
# 11           $  restaurant
# 12    $$ - $$$  restaurant
# 13    $$ - $$$  restaurant
# 14    $$ - $$$  restaurant
# ..         ...         ...
# 295   $$ - $$$  restaurant
# 296   $$ - $$$  restaurant
# 297   $$ - $$$  restaurant
# 298   $$ - $$$  restaurant
# 299       $$$$  restaurant
#
# [290 rows x 2 columns]

# %% [markdown]
# #**Preprocessing**
# Data preprocessing is the process of transforming raw data into an understandable format. It is also an important step in data mining as we cannot work with raw data. The quality of the data should be checked before applying machine learning or data mining algorithms.

# %% [markdown]
# **Missing Values**
# To find the number of null values in the dataframe using .isnull()

# %%
dataset.isnull()
# Out:
#       name  rankingPosition  priceLevel  category  rating  address  \
# 0    False            False       False     False   False    False
# 1    False            False       False     False   False    False
# 2    False            False       False     False   False    False
# 3    False            False       False     False   False    False
# 4    False            False       False     False   False    False
# ..     ...              ...         ...       ...     ...      ...
# 495  False            False       False     False   False    False
# 496  False            False       False     False   False    False
# 497  False            False       False     False   False    False
# 498  False            False       False     False   False    False
# 499  False            False       False     False   False    False
#
#      numberOfReviews
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# ...

# %% [markdown]
# To find the count of total null values

# %%
dataset.isnull().sum()
# Out:
# name               0
# rankingPosition    0
# priceLevel         0
# category           0
# rating             0
# address            0
# numberOfReviews    0
# dtype: int64

# %% [markdown]
# Imported an updated dataframe with some null values to perform operations

# %%
datas=pd.read_csv('/content/melbourne_ta_reviews.csv')

# %%
datas.isnull().sum()
# Out:
# name                0
# rankingPosition     7
# priceLevel          0
# category            0
# rating              4
# address             0
# numberOfReviews    10
# dtype: int64

# %% [markdown]
# finding null values in a particular column

# %%
datas['rating'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: rating, Length: 500, dtype: bool

# %%
datas['rating'].isnull().sum()
# Out:
# 4

# %% [markdown]
# #**Data Cleaning**
#  The process of fixing or removing incorrect, corrupted, incorrectly formatted, duplicate, or incomplete data within a dataset.

# %% [markdown]
# **Filling with zero at null**

# %%
datas.fillna(0)
# Out:
#                              name  rankingPosition priceLevel    category  \
# 0    Hopetoun Tea Rooms est. 1892             26.0   $$ - $$$  restaurant
# 1               Da Guido La Pasta              2.0   $$ - $$$  restaurant
# 2                  Foglia di Fico              3.0   $$ - $$$  restaurant
# 3              Pidapipo Gelateria             11.0          $  restaurant
# 4                        Kazuki's              9.0       $$$$  restaurant
# ..                            ...              ...        ...         ...
# 495                    Bella Cosi            446.0   $$ - $$$  restaurant
# 496           At Ease - Easy Thai            437.0          $  restaurant
# 497                 Lolo and Wren            436.0   $$ - $$$  restaurant
# 498                     Thai city            438.0   $$ - $$$  restaurant
# 499                   Tokui Sushi            429.0          $  restaurant
#
#      rating                                            address  \
# ...

# %% [markdown]
# Dataframe still not updated after performing the function

# %%
datas.isnull().sum()
# Out:
# name                0
# rankingPosition     7
# priceLevel          0
# category            0
# rating              4
# address             0
# numberOfReviews    10
# dtype: int64

# %% [markdown]
# Trying with a random number

# %%
datas.fillna(99)
# Out:
#                              name  rankingPosition priceLevel    category  \
# 0    Hopetoun Tea Rooms est. 1892             26.0   $$ - $$$  restaurant
# 1               Da Guido La Pasta              2.0   $$ - $$$  restaurant
# 2                  Foglia di Fico              3.0   $$ - $$$  restaurant
# 3              Pidapipo Gelateria             11.0          $  restaurant
# 4                        Kazuki's              9.0       $$$$  restaurant
# ..                            ...              ...        ...         ...
# 495                    Bella Cosi            446.0   $$ - $$$  restaurant
# 496           At Ease - Easy Thai            437.0          $  restaurant
# 497                 Lolo and Wren            436.0   $$ - $$$  restaurant
# 498                     Thai city            438.0   $$ - $$$  restaurant
# 499                   Tokui Sushi            429.0          $  restaurant
#
#      rating                                            address  \
# ...

# %%
datas.isnull().sum()
# Out:
# name                0
# rankingPosition     7
# priceLevel          0
# category            0
# rating              4
# address             0
# numberOfReviews    10
# dtype: int64

# %% [markdown]
# **Dropping all values with inconsistency**
#
# Dataframe is still not updated

# %%
datas.dropna()
datas.isnull().sum()
# Out:
# name                0
# rankingPosition     7
# priceLevel          0
# category            0
# rating              4
# address             0
# numberOfReviews    10
# dtype: int64

# %% [markdown]
# **Using inplace parameter**
#
# inplace:bool, default False
# Whether to modify the DataFrame rather than creating a new one.

# %%
datas.dropna(inplace=True)
datas.isnull().sum()
# Out:
# name               0
# rankingPosition    0
# priceLevel         0
# category           0
# rating             0
# address            0
# numberOfReviews    0
# dtype: int64

# %% [markdown]
# #**ASSIGNMENT**
# Random assignment performed in the lab to showcase my understanding in the given session

# %%
data={
    'name':['Ahad','Aman','Bhakti','Aarya','Dev','Darshan','Sujit','Heer','Jai','Anvay'],
    'grade':[3.78,8.93,None,None,3.84,9.99,6.73,7.55,1.90,8.89],
    'year':[2003,2001,1999,2002,2004,None,1998,1978,2018,2025]
}
print(data)
# Out:
# {'name': ['Ahad', 'Aman', 'Bhakti', 'Aarya', 'Dev', 'Darshan', 'Sujit', 'Heer', 'Jai', 'Anvay'], 'grade': [3.78, 8.93, None, None, 3.84, 9.99, 6.73, 7.55, 1.9, 8.89], 'year': [2003, 2001, 1999, 2002, 2004, None, 1998, 1978, 2018, 2025]}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#       name  grade    year
# 0     Ahad   3.78  2003.0
# 1     Aman   8.93  2001.0
# 2   Bhakti    NaN  1999.0
# 3    Aarya    NaN  2002.0
# 4      Dev   3.84  2004.0
# 5  Darshan   9.99     NaN
# 6    Sujit   6.73  1998.0
# 7     Heer   7.55  1978.0
# 8      Jai   1.90  2018.0
# 9    Anvay   8.89  2025.0

# %%
df.head()
# Out:
#      name  grade    year
# 0    Ahad   3.78  2003.0
# 1    Aman   8.93  2001.0
# 2  Bhakti    NaN  1999.0
# 3   Aarya    NaN  2002.0
# 4     Dev   3.84  2004.0

# %%
df.head(20)
# Out:
#       name  grade    year
# 0     Ahad   3.78  2003.0
# 1     Aman   8.93  2001.0
# 2   Bhakti    NaN  1999.0
# 3    Aarya    NaN  2002.0
# 4      Dev   3.84  2004.0
# 5  Darshan   9.99     NaN
# 6    Sujit   6.73  1998.0
# 7     Heer   7.55  1978.0
# 8      Jai   1.90  2018.0
# 9    Anvay   8.89  2025.0

# %%
df.tail()
# Out:
#       name  grade    year
# 5  Darshan   9.99     NaN
# 6    Sujit   6.73  1998.0
# 7     Heer   7.55  1978.0
# 8      Jai   1.90  2018.0
# 9    Anvay   8.89  2025.0

# %%
df.tail(2)
# Out:
#     name  grade    year
# 8    Jai   1.90  2018.0
# 9  Anvay   8.89  2025.0

# %%
df.shape
# Out:
# (10, 3)

# %%
df.size
# Out:
# 30

# %%
df.columns
# Out:
# Index(['name', 'grade', 'year'], dtype='object')

# %%
df.dtypes
# Out:
# name      object
# grade    float64
# year     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    10 non-null     object
#  1   grade   8 non-null      float64
#  2   year    9 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       name  grade    year
# 0     Ahad   3.78  2003.0
# 1     Aman   8.93  2001.0
# 2   Bhakti    NaN  1999.0
# 3    Aarya    NaN  2002.0
# 4      Dev   3.84  2004.0
# 5  Darshan   9.99     NaN
# 6    Sujit   6.73  1998.0
# 7     Heer   7.55  1978.0
# 8      Jai   1.90  2018.0
# 9    Anvay   8.89  2025.0>

# %%
print(df[0:5]['name'])
# Out:
# 0      Ahad
# 1      Aman
# 2    Bhakti
# 3     Aarya
# 4       Dev
# Name: name, dtype: object

# %%
print(df.loc[3:7,['grade','name']])
# Out:
#    grade     name
# 3    NaN    Aarya
# 4   3.84      Dev
# 5   9.99  Darshan
# 6   6.73    Sujit
# 7   7.55     Heer

# %%
print(df.iloc[2:5,[0,2]])
# Out:
#      name    year
# 2  Bhakti  1999.0
# 3   Aarya  2002.0
# 4     Dev  2004.0

# %%
df.isnull()
# Out:
#     name  grade   year
# 0  False  False  False
# 1  False  False  False
# 2  False   True  False
# 3  False   True  False
# 4  False  False  False
# 5  False  False   True
# 6  False  False  False
# 7  False  False  False
# 8  False  False  False
# 9  False  False  False

# %%
df.isnull().sum()
# Out:
# name     0
# grade    2
# year     1
# dtype: int64

# %%
df['grade'].isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: grade, dtype: bool

# %%
df['grade'].isnull().sum()
# Out:
# 2

# %%
df.fillna(0)
# Out:
#       name  grade    year
# 0     Ahad   3.78  2003.0
# 1     Aman   8.93  2001.0
# 2   Bhakti   0.00  1999.0
# 3    Aarya   0.00  2002.0
# 4      Dev   3.84  2004.0
# 5  Darshan   9.99     0.0
# 6    Sujit   6.73  1998.0
# 7     Heer   7.55  1978.0
# 8      Jai   1.90  2018.0
# 9    Anvay   8.89  2025.0

# %%
df.describe()
# Out:
#           grade         year
# count  8.000000     9.000000
# mean   6.451250  2003.111111
# std    2.941513    13.138155
# min    1.900000  1978.000000
# 25%    3.825000  1999.000000
# 50%    7.140000  2002.000000
# 75%    8.900000  2004.000000
# max    9.990000  2025.000000

# %%
df.isnull().sum()
# Out:
# name     0
# grade    2
# year     1
# dtype: int64

# %%
df.dropna()
df.isnull().sum()
# Out:
# name     0
# grade    2
# year     1
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# name     0
# grade    0
# year     0
# dtype: int64
